# %% [markdown]
# # Management Rapportage F&R

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas import *
mwFile = '/Users/martin/Desktop/Work/MWInput.xlsx'
mwXlsFile = pd.ExcelFile(mwFile)
mwDF = mwXlsFile.parse('Sheet1')
#mwDF.to_excel('/Users/martin/Desktop/Work/mwDF.xlsx', sheet_name='Sheet1')


#mwDF1 = mwDF[(mwDF.Bedrijfsonderdeel == 'I&C Finance & Risk')& (mwDF.Projectbron == 'Adaptief Onderhoud')]
mwDF1 = mwDF[(mwDF.Bedrijfsonderdeel == 'I&C Finance & Risk')]
#mwDF1.to_excel('/Users/martin/Desktop/Work/mwDF1.xlsx', sheet_name='Sheet2')
mwDF2 = mwDF[(mwDF.Opdrachtnemer == 'I&C Finance & Risk')]
#mwDF2.to_excel('/Users/martin/Desktop/Work/mwDF2.xlsx', sheet_name='Sheet3')

#writer = ExcelWriter('/Users/martin/Desktop/Work/mwDF.xlsx')
#mwDF.to_excel(writer,'Sheet1')
#mwDF1.to_excel(writer,'Sheet2')
#mwDF2.to_excel(writer,'Sheet3')
#writer.save()
# %matplotlib inline

# %%
#mwDF.head()
#mwDF.tail()
#mwDF.columns
#mwDF.describe()
#mwDF.values
#mwDF.sort(columns='Bedrijfsonderdeel')
#mwDF['Bedrijfsonderdeel']

#df = DataFrame(np.random.randint(0,10,size=100).reshape(10,10))
#Series(df.values.ravel()).unique()

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))

# %%
ts = ts.cumsum()

# %%
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list('ABCD'))

# %%
df = df.cumsum()

# %%
plt.figure();

# %%
df.plot();

# %%
df3 = pd.DataFrame(np.random.randn(1000, 2), columns=['B', 'C']).cumsum()

# %%
df3['A'] = pd.Series(list(range(len(df))))

# %%
df3.plot(x='A', y='B')

# %%
plt.figure();

# %%
df.ix[5].plot(kind='bar'); plt.axhline(0, color='k')

# %%
df2 = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])

# %%
df2.plot(kind='bar');

# %%
df2.plot(kind='bar', stacked=True);

# %%
df2.plot(kind='barh', stacked=True);

# %%
df4 = pd.DataFrame({'a': np.random.randn(1000) + 1, 'b': np.random.randn(1000),
    'c': np.random.randn(1000) - 1}, columns=['a', 'b', 'c'])

# %%
plt.figure();

# %%
df4.plot(kind='hist', alpha=0.5)

# %%
plt.figure();

# %%
df4['a'].plot(kind='hist', orientation='horizontal', cumulative=True)

# %%
plt.figure();

# %%
df['A'].diff().hist()

# %%
plt.figure();

# %%
df.diff().hist(color='k', alpha=0.5, bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1127183c8>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113133128>]], dtype=object)

# %%
df = pd.DataFrame(np.random.rand(10, 5), columns=['A', 'B', 'C', 'D', 'E'])

# %%
df.plot(kind='box')

# %%
color = dict(boxes='DarkGreen', whiskers='DarkOrange',
    medians='DarkBlue', caps='Gray')

# %%
df.plot(kind='box', color=color, sym='r+')

# %%
df.plot(kind='box', vert=False, positions=[1, 4, 5, 6, 8])

# %%
df = pd.DataFrame(np.random.rand(10,5))

# %%
plt.figure();

# %%
bp = df.boxplot()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/pandas/tools/plotting.py:2633: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
#   warnings.warn(msg, FutureWarning)

# %%
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])

# %%
df.plot(kind='area');

# %%
df.plot(kind='area', stacked=False);

# %%
df = pd.DataFrame(np.random.rand(50, 4), columns=['a', 'b', 'c', 'd'])

# %%
df.plot(kind='scatter', x='a', y='b');

# %%
ax = df.plot(kind='scatter', x='a', y='b',
    color='DarkBlue', label='Group 1');

# %%
df.plot(kind='scatter', x='c', y='d',
    color='DarkGreen', label='Group 2', ax=ax);

# %%
df.plot(kind='scatter', x='a', y='b', c='c', s=50);

# %%
df.plot(kind='scatter', x='a', y='b', s=df['c']*200);

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])

# %%
df['b'] = df['b'] + np.arange(1000)

# %%
df.plot(kind='hexbin', x='a', y='b', gridsize=25)

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])

# %%
df['b'] = df['b'] = df['b'] + np.arange(1000)

# %%
df['z'] = np.random.uniform(0, 3, 1000)

# %%
df.plot(kind='hexbin', x='a', y='b', C='z', reduce_C_function=np.max,
    gridsize=25)

# %%
series = pd.Series(3 * np.random.rand(4), index=['a', 'b', 'c', 'd'], name='series')

# %%
series.plot(kind='pie', figsize=(6, 6))

# %%
df = pd.DataFrame(3 * np.random.rand(4, 2), index=['a', 'b', 'c', 'd'], columns=['x', 'y'])

# %%
df.plot(kind='pie', subplots=True, figsize=(8, 4))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x114fd1cf8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x115237588>], dtype=object)

# %%
series.plot(kind='pie', labels=['AA', 'BB', 'CC', 'DD'], colors=['r', 'g', 'b', 'c'],
    autopct='%.2f', fontsize=20, figsize=(6, 6))

# %%
series.plot(kind='pie', labels=['AA', 'BB', 'CC', 'DD'], colors=['r', 'g', 'b', 'c'],
    autopct='%.2f', fontsize=20, figsize=(6, 6))

# %%
series = pd.Series([0.1] * 4, index=['a', 'b', 'c', 'd'], name='series2')

# %%
series.plot(kind='pie', figsize=(6, 6))

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list('ABCD'))

# %%
df = df.cumsum()

# %%
df.plot(legend=False)

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))

# %%
ts = np.exp(ts.cumsum())

# %%
ts.plot(logy=True)

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))

# %%
ts = np.exp(ts.cumsum())

# %%
ts.plot(logy=True)

# %%
df.A.plot()

# %%
df.B.plot(secondary_y=True, style='g')

# %%
plt.figure()

# %%
ax = df.plot(secondary_y=['A', 'B'])

# %%
ax.set_ylabel('CD scale')

# %%
ax.right_ax.set_ylabel('AB scale')

# %%
plt.figure()

# %%
df.A.plot(x_compat=True)

# %%
plt.figure()

# %%
with pd.plot_params.use('x_compat', True):
    df.A.plot(color='r')
    df.B.plot(color='g')
    df.C.plot(color='b')

# %%
df.plot(subplots=True, figsize=(6, 6));

# %%
df.plot(subplots=True, layout=(2, 3), figsize=(6, 6), sharex=False);

# %%
df.plot(subplots=True, layout=(2, -1), figsize=(6, 6), sharex=False);

# %%
fig, ax = plt.subplots(1, 1)
df = pd.DataFrame(np.random.rand(5, 3), columns=['a', 'b', 'c'])
ax.get_xaxis().set_visible(False) # Hide Ticks
df.plot(table=True, ax=ax)

# %%
fig, ax = plt.subplots(1, 1)
ax.get_xaxis().set_visible(False) # Hide Ticks
df.plot(table=np.round(df.T, 2), ax=ax)

# %%
df = pd.DataFrame(np.random.randn(1000, 10), index=ts.index)
df = df.cumsum()
plt.figure()
df.plot(colormap='cubehelix')

# %%
from matplotlib import cm
plt.figure()
df.plot(colormap=cm.cubehelix)

# %%
dd = pd.DataFrame(np.random.randn(10, 10)).applymap(abs)
dd = dd.cumsum()
plt.figure()
dd.plot(kind='bar', colormap='Greens')

# %%
price = pd.Series(np.random.randn(150).cumsum(),
    index=pd.date_range('2000-1-1', periods=150, freq='B'))
ma = pd.rolling_mean(price, 20)
mstd = pd.rolling_std(price, 20)
plt.figure()
plt.plot(price.index, price, 'k')
plt.plot(ma.index, ma, 'b')
plt.fill_between(mstd.index, ma-2*mstd, ma+2*mstd, color='b', alpha=0.2)

# %%
plt.figure()
plot = rplot.RPlot(tips_data, x='total_bill', y='tip')
plot.add(rplot.TrellisGrid(['sex', 'smoker']))
plot.add(rplot.GeomHistogram())
plot.render(plt.gcf())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-126-6bead37263f5> in <module>()
#       1 plt.figure()
# ----> 2 plot = rplot.RPlot(tips_data, x='total_bill', y='tip')
#       3 plot.add(rplot.TrellisGrid(['sex', 'smoker']))
#       4 plot.add(rplot.GeomHistogram())
#       5 plot.render(plt.gcf())
#
# NameError: name 'rplot' is not defined

# %%
plt.figure()
plot = rplot.RPlot(tips_data, x='total_bill', y='tip')
plot.add(rplot.TrellisGrid(['sex', 'smoker']))
plot.add(rplot.GeomDensity())
plot.render(plt.gcf())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-127-145602d42630> in <module>()
#       1 plt.figure()
# ----> 2 plot = rplot.RPlot(tips_data, x='total_bill', y='tip')
#       3 plot.add(rplot.TrellisGrid(['sex', 'smoker']))
#       4 plot.add(rplot.GeomDensity())
#       5 plot.render(plt.gcf())
#
# NameError: name 'rplot' is not defined
