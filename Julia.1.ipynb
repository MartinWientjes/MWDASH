# %%
using PyPlot

# %%
α = 3
# Out:
# 3

# %%
println(α)
# Out:
# 3

# %%
f(x) = 2x^2 + 3x +1
# Out:
# f (generic function with 1 method)

# %%
g(x) = f(x) - (2x+1)*(x+1)
# Out:
# g (generic function with 1 method)

# %%
f(3)
# Out:
# 28

# %%
g(3.5)
# Out:
# 0.0

# %%
a = Int8(1)
b = Int8(2)
a + b
# Out:
# 3

# %%
typeof(ans)
# Out:
# Int8

# %%
big(10)
# Out:
# 10

# %%
typeof(ans)
# Out:
# BigInt

# %%
10^10
# Out:
# 10000000000

# %%
I = [3,4,5]
# Out:
# 3-element Array{Int64,1}:
#  3
#  4
#  5

# %%
typeof(I)
# Out:
# Array{Int64,1}

# %%
names(I)
# Out:
# WARNING: names(v) is deprecated, use fieldnames(v) instead.
# 0-element Array{Symbol,1}

# %%
methods(push!)
# Out:
#  in depwarn at deprecated.jl:73
#  in names at deprecated.jl:50
#  in include_string at loading.jl:266
#  in execute_request_0x535c5df2 at /Users/martin/.julia/v0.4/IJulia/src/execute_request.jl:177
#  in eventloop at /Users/martin/.julia/v0.4/IJulia/src/IJulia.jl:141
#  in anonymous at task.jl:447
# while loading In[33], in expression starting on line 1
# # 19 methods for generic function "push!":
# push!(a::Array{Any,1}, item::ANY) at array.jl:439
# push!{T}(a::Array{T,1}, item) at array.jl:432
# push!(B::BitArray{1}, item) at bitarray.jl:430
# push!(s::IntSet, n::Integer) at intset.jl:51
# push!(t::Associative{K,V}, p::Pair{A,B}) at dict.jl:294
# push!(t::Associative{K,V}, p::Pair{A,B}, q::Pair{A,B}) at dict.jl:295
# push!(t::Associative{K,V}, p::Pair{A,B}, q::Pair{A,B}, r::Pair{A,B}...) at dict.jl:296
# push!(s::Set{T}, x) at set.jl:29
# push!(::Base.EnvHash, k::AbstractString, v) at env.jl:94
# push!(c::CompositeException, ex) at task.jl:42
# ...

# %%
push!(I,7)
# Out:
# 4-element Array{Int64,1}:
#  3
#  4
#  5
#  7

# %%
methodswith(Array)
# Out:
# 341-element Array{Method,1}:
#  *{T,S}(s::Base.LinAlg.SVDOperator{T,S}, v::Array{T,1}) at linalg/arnoldi.jl:261
#  +(A::Array{T,N}, B::SparseMatrixCSC{Tv,Ti<:Integer}) at sparse/sparsematrix.jl:1019
#  +(A::SparseMatrixCSC{Tv,Ti<:Integer}, B::Array{T,N}) at sparse/sparsematrix.jl:1017
#  -(A::Array{T,N}, B::SparseMatrixCSC{Tv,Ti<:Integer}) at sparse/sparsematrix.jl:1024
#  -(A::SparseMatrixCSC{Tv,Ti<:Integer}, B::Array{T,N}) at sparse/sparsematrix.jl:1022
#  ./(A::SparseMatrixCSC{Tv,Ti<:Integer}, B::Array{T,N}) at sparse/sparsematrix.jl:1032
#  ./(A::Array{T,N}, B::SparseMatrixCSC{Tv,Ti<:Integer}) at sparse/sparsematrix.jl:1033
#  .\(A::SparseMatrixCSC{Tv,Ti<:Integer}, B::Array{T,N}) at sparse/sparsematrix.jl:1038
#  .\(A::Array{T,N}, B::SparseMatrixCSC{Tv,Ti<:Integer}) at sparse/sparsematrix.jl:1039
#  .^{T<:Integer}(A::BitArray{N}, B::Array{T<:Integer,N}) at broadcast.jl:449
#  .^(A::SparseMatrixCSC{Tv,Ti<:Integer}, B::Array{T,N}) at sparse/sparsematrix.jl:1046
# ...

# %%
sizehint
# Out:
# sizehint (generic function with 1 method)

# %%
size(I)
# Out:
# (4,)

# %%
append!(1, [10,11,12])
# Out:
# LoadError: MethodError: `append!` has no method matching append!(::Int64, ::Array{Int64,1})
# Closest candidates are:
#   append!{T}(!Matched::Array{T,1}, ::AbstractArray{T,1})
#   append!{T}(!Matched::PyCall.PyVector{T}, ::Any)
#   append!(!Matched::PyCall.PyObject, ::Any)
# while loading In[40], in expression starting on line 1

# %%
methodswith(append!)
# Out:
# LoadError: MethodError: `methodswith` has no method matching methodswith(::Function)
# while loading In[42], in expression starting on line 1

# %%
a = (1.1, 2.2, 3.4)
# Out:
# (1.1,2.2,3.4)

# %%
b = [4.4, 5.5, 6.6]
# Out:
# 3-element Array{Float64,1}:
#  4.4
#  5.5
#  6.6

# %%
typeof(a)
# Out:
# Tuple{Float64,Float64,Float64}

# %%
a + b
# Out:
# LoadError: MethodError: `+` has no method matching +(::Tuple{Float64,Float64,Float64}, ::Array{Float64,1})
# Closest candidates are:
#   +(::Any, ::Any, !Matched::Any, !Matched::Any...)
#   +{S,T}(!Matched::Range{S}, ::AbstractArray{T,N})
#   +(!Matched::SparseMatrixCSC{Tv,Ti<:Integer}, ::Array{T,N})
#   ...
# while loading In[47], in expression starting on line 1

# %%
3.5 * a
# Out:
# LoadError: MethodError: `*` has no method matching *(::Float64, ::Tuple{Float64,Float64,Float64})
# Closest candidates are:
#   *(::Any, ::Any, !Matched::Any, !Matched::Any...)
#   *(::Float64, !Matched::Float64)
#   *(::Real, !Matched::Complex{Bool})
#   ...
# while loading In[48], in expression starting on line 1

# %%
3,4 .* a
# Out:
# LoadError: MethodError: `.*` has no method matching .*(::Int64, ::Tuple{Float64,Float64,Float64})
# Closest candidates are:
#   .*(::Real, !Matched::OrdinalRange{T,S})
#   .*(::Real, !Matched::FloatRange{T<:AbstractFloat})
#   .*(::Real, !Matched::LinSpace{T<:AbstractFloat})
#   ...
# while loading In[49], in expression starting on line 1

# %%
dot(I, ans)
# Out:
# LoadError: MethodError: `dot` has no method matching dot(::Array{Int64,1}, ::Type{Tuple{Float64,Float64,Float64}})
# Closest candidates are:
#   dot(::AbstractArray{T,1}, !Matched::AbstractArray{T,1})
# while loading In[50], in expression starting on line 1

# %%
cross(a,b)
# Out:
# LoadError: MethodError: `cross` has no method matching cross(::Tuple{Float64,Float64,Float64}, ::Array{Float64,1})
# Closest candidates are:
#   cross(!Matched::AbstractArray{T,1}, ::AbstractArray{T,1})
# while loading In[51], in expression starting on line 1

# %%
norm(a)
# Out:
# LoadError: MethodError: `norm` has no method matching norm(::Tuple{Float64,Float64,Float64})
# while loading In[58], in expression starting on line 1

# %%
?dot
# Out:
# search:
# ```
# dot(x, y)
# ⋅(x,y)
# ```
#
# Compute the dot product. For complex vectors, the first vector is conjugated.
# dot vecdot STDOUT @doc_str midpoints FixedPointNumbers fieldoffsets

# %%
?cross
# Out:
# search:
# ```
# cross(x, y)
# ×(x,y)
# ```
#
# Compute the cross product of two 3-vectors.
# cross LocalProcess ctranspose ctranspose! count_zeros

# %%
?norm
# Out:
# search:
# ```rst
# ..  norm(A, [p])
#
# Compute the ``p``-norm of a vector or the operator norm of a matrix ``A``, defaulting to the ``p=2``-norm.
#
# For vectors, ``p`` can assume any numeric value (even though not all values produce a mathematically valid vector norm). In particular, ``norm(A, Inf)`` returns the largest value in ``abs(A)``, whereas ``norm(A, -Inf)`` returns the smallest.
#
# For matrices, the matrix norm induced by the vector ``p``-norm is used, where valid values of ``p`` are ``1``, ``2``, or ``Inf``. (Note that for sparse matrices, ``p=2`` is currently not implemented.) Use :func:`vecnorm` to compute the Frobenius norm.
# ```
# norm normpath normalize_string vecnorm issubnormal UniformScaling

# %%
dot(a,b)
# Out:
# LoadError: MethodError: `dot` has no method matching dot(::Tuple{Float64,Float64,Float64}, ::Array{Float64,1})
# Closest candidates are:
#   dot(!Matched::AbstractArray{T,1}, ::AbstractArray{T,1})
# while loading In[59], in expression starting on line 1

# %%
transpose(a)
# Out:
# (1.1,2.2,3.4)

# %%
?transpose
# Out:
# search:
# ```
# transpose(A)
# ```
#
# The transposition operator (`.'`).
# transpose transpose! ctranspose ctranspose!

# %%
pkg.update()
# Out:
# LoadError: UndefVarError: pkg not defined
# while loading In[1], in expression starting on line 1
