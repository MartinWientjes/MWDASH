# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
MWBestand1 = '/Users/martin/Desktop/SNS/CSV/FLEX_Instandhouding.xlsx'
MWBestand2 = '/Users/martin/Desktop/SNS/CSV/lijnproject.xlsx'
A = pd.read_excel(MWBestand1, "Sheet1", index_col=None, na_values=["NA"])
B = pd.read_excel(MWBestand2, "Sheet1", index_col=None, na_values=["NA"])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-3c9a8b0e3bef> in <module>()
#       4 MWBestand1 = '/Users/martin/Desktop/SNS/CSV/FLEX_Instandhouding.xlsx'
#       5 MWBestand2 = '/Users/martin/Desktop/SNS/CSV/lijnproject.xlsx'
# ----> 6 A = pd.read_excel(MWBestand1, "Sheet1", index_col=None, na_values=["NA"])
#       7 B = pd.read_excel(MWBestand2, "Sheet1", index_col=None, na_values=["NA"])
#
# //anaconda/lib/python3.4/site-packages/pandas/io/excel.py in read_excel(io, sheetname, **kwds)
#     149     engine = kwds.pop('engine', None)
#     150
# --> 151     return ExcelFile(io, engine=engine).parse(sheetname=sheetname, **kwds)
#     152
#     153
#
# //anaconda/lib/python3.4/site-packages/pandas/io/excel.py in __init__(self, io, **kwds)
#     186                 self.book = xlrd.open_workbook(file_contents=data)
#     187             else:
# ...

# %%
A.describe()
# Out:
#        Opdrachtgever  Prioriteit     IP_V20_AB     IP_V20_ONT  IP_V20_VP  \
# count             46          46    499.000000     499.000000        499
# mean               0           0     62.659319     285.260521          0
# std                0           0   1399.703153    6372.237352          0
# min                0           0      0.000000       0.000000          0
# 25%                0           0      0.000000       0.000000          0
# 50%                0           0      0.000000       0.000000          0
# 75%                0           0      0.000000       0.000000          0
# max                0           0  31267.000000  142345.000000          0
#
#        IP_V20_IO  IP_V20_OV  IP_V20_VV   IP_V20_VO3  IP_V99_AB    IP_V99_ONT  \
# count        499        499        499    499.00000        499    499.000000
# mean           0          0          0     46.97996          0    284.458918
# std            0          0          0   1049.45281          0   1228.840032
# ...

# %%
B.describe()
# Out:
#         Totaal Uren        201401        201402        201403        201404  \
# count  54999.000000  54999.000000  54999.000000  54999.000000  54999.000000
# mean      30.888059      4.598875      4.046538      4.271426      4.432370
# std       84.756074     16.533610     15.102792     15.930711     15.267672
# min      -64.000000     -8.000000      0.000000    -20.000000     -8.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        4.000000      0.000000      0.000000      0.000000      0.000000
# 75%       24.000000      0.500000      0.000000      0.000000      0.500000
# max     1426.000000    304.000000    228.000000    298.000000    212.650000
#
#              201405        201406        201407        201408        201409  \
# count  54999.000000  54999.000000  54999.000000  54999.000000  54999.000000
# mean       4.387224      4.205377      4.161608      0.616749      0.081381
# ...

# %%
pd.pivot_table(B, 
            values="Totaal Uren", 
            rows = ["Bedrijfsonderdeel", "Projectnaam"], 
            columns=["Afdeling"], 
            aggfunc=pd.sum)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-b53c1d78ddef> in <module>()
#       3             rows = ["Bedrijfsonderdeel", "Projectnaam"],
#       4             columns=["Afdeling"],
# ----> 5             aggfunc=pd.sum)
#
# AttributeError: 'module' object has no attribute 'sum'

# %%
A.shape
# Out:
# (499, 168)

# %%
B.shape
# Out:
# (54999, 32)

# %%
A.

# %%
pd.pivot_table?
